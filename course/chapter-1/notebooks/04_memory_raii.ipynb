# %% [markdown]
# # 04 — Optional: References & Lifetime (Preview)
# This preview shows how references and scope affect values and object lifetimes.

# %%
#include <iostream>

struct ScopeLog {
  const char* name;
  explicit ScopeLog(const char* n) : name(n) { std::cout << "enter " << name << "\n"; }
  ~ScopeLog() { std::cout << "exit  " << name << "\n"; }
};

ScopeLog s("main");
int x = 10;
int& ref = x;
ref += 5;
std::cout << x << std::endl;

# %%
// TODO: edit and re-run this cell
// Add a nested scope and log order
{
  // ScopeLog inner("inner");
}

// Try making x const and see what changes
// const int x = 10;

# %% [markdown]
# ## Tasks
# 1. Add a second `ScopeLog` inside a nested block and observe the order.
# 2. Make `x` const and explain what fails.
