# %% [markdown]
# # 05 — Core containers

# %%
#include <iostream>
#include <string>
#include <vector>
#include <array>

std::string s = "hello";
std::vector<int> v{1,2,3};
std::array<int, 3> a{4,5,6};
v.push_back(4);

std::cout << s << " size=" << s.size() << "\n";
std::cout << "v size=" << v.size() << "\n";
std::cout << "a[1]=" << a[1] << std::endl;

# %%
// TODO: edit and re-run this cell
std::string t = "abcdef";
// reverse t
std::cout << t << std::endl;

std::vector<double> nums{1.0, 2.0, 3.0, 4.0};
double avg = 0.0;
// compute avg
std::cout << avg << std::endl;

# %% [markdown]
# ## Tasks
# 1. Reverse a string in-place.
# 2. Compute the average of a vector.
