// %% [markdown]
// # 01 — Tooling & xcpp workflow
// This notebook verifies the xcpp setup and include paths.

// %%
#include <iostream>

std::cout << "xcpp ready" << std::endl;
// Out:
// xcpp ready

// %%
// TODO: edit and re-run this cell
// Example: use a helper from mcppfa
#include "mcppfa/core/strings.hpp"

auto parts = mcppfa::split("hello   xcpp");
std::cout << "parts=" << parts.size() << std::endl;
// Out:
// parts=2

// %% [markdown]
// ## Tasks
// 1. Change the message to print your name.
// 2. Include one additional header from include/mcppfa and call a function.
