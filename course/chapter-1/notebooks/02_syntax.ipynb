// %% [markdown]
// # 02 — Basics: Hello World, Variables, Types, I/O
// This notebook introduces basic syntax, types, and simple input/output.

// %%
#include <iostream>
#include <string>

std::string name = "Ada";
int age = 20;
double radius = 2.5;
double area = 3.14159 * radius * radius;
bool adult = (age >= 18);

std::cout << "Hello, " << name << "!" << std::endl;
std::cout << "area=" << area << " adult=" << adult << std::endl;

// Try switching to input instead:
// std::cin >> name >> age;

// %%
## Tasks
1. Modify the greeting to include both name and age.
2. Change the radius and observe the area output.

// %% [markdown]
// // TODO: edit and re-run this cell
// std::string user = "YourName";
// std::cout << "Hello, " << user << "!" << std::endl;
//
// double r = 1.0;
// double area = 3.14159 * r * r;
// std::cout << "area=" << area << std::endl;
