// %% [markdown]
// # 02 — Types, variables, expressions, control flow

// %%
#include <iostream>
#include <vector>

int x = 5;
double y = 3.14;
bool ok = (x > 2);

int sum = 0;
for (int i = 1; i <= 10; ++i) sum += i;

std::cout << "sum=" << sum << " ok=" << ok << " y=" << y << std::endl;
// Out:
// sum=55 ok=1 y=3.14

// %%
// TODO: edit and re-run this cell
int fact = 1;
for (int i = 1; i <= 6; ++i) {
  // update fact
}

int sum_even = 0;
for (int i = 1; i <= 100; ++i) {
  // add even numbers
}

std::cout << "fact=" << fact << " sum_even=" << sum_even << std::endl;
// Out:
// fact=1 sum_even=0

// %% [markdown]
// ## Tasks
// 1. Compute factorial of 6 in a loop.
// 2. Sum only even numbers from 1..100.
