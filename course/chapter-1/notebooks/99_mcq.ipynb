# %% [markdown]
# # Chapter 1 — MCQ
# Answer by editing the cell below.

# %% [markdown]
# ## Questions
# 1) Which container is dynamically sized?
# A. std::array
# B. std::vector
# C. C array
#
# 2) What does RAII mean?
# A. Resource Acquisition Is Initialization
# B. Random Access In Iteration
# C. Read And Inspect Integers
#
# 3) What does `const` on a reference parameter mean?
# A. The reference cannot be reseated
# B. The referenced object cannot be modified via that reference
# C. The reference is always null
#
# 4) Which loop is best for iterating a vector?
# A. range-for
# B. goto
# C. do-while only

# %%
// TODO: write your answers as letters, e.g.
// Q1: B
// Q2: A
// Q3: B
// Q4: A
