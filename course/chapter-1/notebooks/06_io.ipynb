# %% [markdown]
# # 06 — Streams and formatting

# %%
#include <iostream>
#include <iomanip>

double x = 3.1415926;
std::cout << std::fixed << std::setprecision(3) << x << std::endl;

# %%
// TODO: edit and re-run this cell
double v = 9.87654;
std::cout << std::fixed << std::setprecision(2) << v << std::endl;

// std::string line;
// std::getline(std::cin, line);
// std::cout << line.size() << std::endl;

# %% [markdown]
# ## Tasks
# 1. Print the value with 2 decimals.
# 2. Read a line and print its length.
