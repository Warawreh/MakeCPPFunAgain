// %% [markdown]
// # 03 — Mini Project: Greeting & Calculator
// A small project that practices variables, arithmetic, and output without defining functions.

// %%
#include <iostream>
#include <string>

std::string name = "Sam";
int a = 8;
int b = 3;

std::cout << "Hello, " << name << "!" << std::endl;
std::cout << "a+b=" << (a + b) << " a-b=" << (a - b) << std::endl;
std::cout << "a*b=" << (a * b) << " a/b=" << (a / b) << std::endl;
// Out:
// max=5
// mean=2

// %%
## Tasks
1. Change the numbers and observe the results.
2. Add another operation (e.g., modulus) and print it.
// Out:
// max=5.4
// median=2

// %% [markdown]
// // TODO: edit and re-run this cell
// std::string name = "YourName";
// int x = 10;
// int y = 4;
//
// std::cout << "Welcome, " << name << "!" << std::endl;
// std::cout << "x+y=" << (x + y) << " x-y=" << (x - y) << std::endl;
// std::cout << "x*y=" << (x * y) << " x/y=" << (x / y) << std::endl;
