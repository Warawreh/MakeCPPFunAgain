// %% [markdown]
// # 02 — First xcpp notebook
// This notebook uses repo includes without LibTorch to avoid missing torch headers.
// If you have LibTorch installed, you can include `include/mcppfa/notebook_setup.hpp` in your own cells.

// %%
#include <mcppfa/core/strings.hpp>
#include <iostream>

auto parts = mcppfa::split("notebook setup ok");
std::cout << parts.size() << std::endl;

// %% [markdown]
// ## Tasks
// 1. Include another header from include/mcppfa.
// 2. Call any function from that header.

// %%
// TODO: edit and re-run this cell
#include <mcppfa/core/strings.hpp>
auto parts = mcppfa::split("a  b  c");
std::cout << parts.size() << std::endl;
