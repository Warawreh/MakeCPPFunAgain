# %% [markdown]
# # Chapter 0 — MCQ
# Answer by editing the cell below.

# %% [markdown]
# ## Questions
# 1) What does xcpp provide?
# A. A C++ kernel for notebooks
# B. A Python-only REPL
# C. A C++ web framework
#
# 2) Why include `include/mcppfa/notebook_setup.hpp`?
# A. It sets include paths for this repo
# B. It compiles all project code
# C. It runs tests automatically
#
# 3) In notebooks, cells run in what order?
# A. The order you execute them
# B. Always top to bottom automatically
# C. Random order

# %%
// TODO: write your answers as letters, e.g.
// Q1: A
// Q2: A
// Q3: A
