// %% [markdown]
// # 01 — Setup and verify xcpp
// Run the cell below to verify your kernel.

// %%
#include <iostream>
std::cout << "xcpp kernel OK" << std::endl;

// %% [markdown]
// ## Tasks
// 1. Change the message.
// 2. Add a second line with your name.

// %%
// TODO: edit and re-run this cell
std::cout << "hello" << std::endl;
